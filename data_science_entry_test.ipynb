# %% [markdown]
# **1. Variable Swapping**
#
# *Task: Create a function to swap two numeric values using only the provided variables*

# %%
def swap(x, y):
    # Check if both inputs are numeric (int or float)
    if not (isinstance(x, (int, float)) and isinstance(y, (int, float))):
        return -1

    # Swapping using only x and y via tuple unpacking
    x, y = y, x

    print(f"Swapped values: x = {x}, y = {y}")

# Scenario 1: Non-numeric input
result1 = swap("Apple", 10)
if result1 == -1:
    print(f"Scenario 1 result: {result1} (Non-numeric input)")

# Scenario 2: Numeric input
swap(9, 17)
# Out:
# Scenario 1 result: -1 (Non-numeric input)
# Swapped values: x = 17, y = 9

# %% [markdown]
# **2. List Find and Replace**
#
# *Task: Search for all occurrences of a value in a list and replace them in-place.*

# %%
def find_and_replace(lst, find_val, replace_val):
    """
    Task 1
    - Searches for all occurrences of find_val and replaces them with replace_val.
    """
    # We use a range-based loop to modify the list in-place via index
    for i in range(len(lst)):
        if lst[i] == find_val:
            lst[i] = replace_val
    return lst

# Task 2: Invoking the function
scenario_1 = find_and_replace([1, 2, 3, 4, 2, 2], 2, 5)
scenario_2 = find_and_replace(["apple", "banana", "apple"], "apple", "orange")

print(f"Scenario 1: {scenario_1}")
print(f"Scenario 2: {scenario_2}")
# Out:
# Scenario 1: [1, 5, 3, 4, 5, 5]
# Scenario 2: ['orange', 'banana', 'orange']

# %% [markdown]
# **3. Dictionary Updates**
#
# *Task: Update a dictionary with a key-value pair and print the original value if the key already exists.*

# %%
def update_dictionary(dct, key, value):
    """
    Task 1
    - Updates a dictionary with a new key-value pair.
    - If key exists, prints original value before updating.
    """
    if key in dct:
        print(f"Original value for '{key}': {dct[key]}")

    # Updating or adding the key-value pair
    dct[key] = value
    return dct


# Task 2: Invoking the function
scenario_1 = update_dictionary({}, "name", "Alice")
scenario_2 = update_dictionary({"age": 25}, "age", 26)

print(f"Result 1: {scenario_1}")
print(f"Result 2: {scenario_2}")
# Out:
# Original value for 'age': 25
# Result 1: {'name': 'Alice'}
# Result 2: {'age': 26}

# %% [markdown]
# **4. String Reversal**
#
# *Task: Reverse a string using Python slicing syntax.*

# %%
def string_reverse(s):
    """
    Task 1
    - Reverses a given string (s) using slicing.
    - Returns the reversed string.
    """
    # Syntax: string[start:stop:step]
    # A step of -1 tells Python to move backwards through the string
    return s[::-1]

# Task 2: Invoking the function
scenario_1 = string_reverse("Hello World")
scenario_2 = string_reverse("Python")

print(f"Scenario 1: {scenario_1}")
print(f"Scenario 2: {scenario_2}")
# Out:
# Scenario 1: dlroW olleH
# Scenario 2: nohtyP

# %% [markdown]
# **5. Divisibility Check**
#
# *Task: Determine if a number is divisible by a divisor, handling division by zero.*

# %%
def check_divisibility(num, divisor):
    """
    Task 1
    - Checks if num is divisible by divisor.
    - Returns True if remainder is 0, False otherwise.
    """
    # Guard against division by zero to prevent a ZeroDivisionError
    if divisor == 0:
        return False

    return num % divisor == 0


# Task 2: Invoking the function
scenario_1 = check_divisibility(10, 2)
scenario_2 = check_divisibility(7, 3)

print(f"Is 10 divisible by 2? {scenario_1}")
print(f"Is 7 divisible by 3? {scenario_2}")
# Out:
# Is 10 divisible by 2? True
# Is 7 divisible by 3? False

# %% [markdown]
# **6. Find First Negative**
#
# *Task: Use a while loop to find and return the first negative integer in a list.*

# %%
def find_first_negative(lst):
    """
    Task 1
    - Finds the first negative number using a while loop.
    """
    i = 0
    # Loop as long as 'i' is within the list boundaries
    while i < len(lst):
        if lst[i] < 0:
            return lst[i]  # Return immediately when found
        i += 1  # Move to the next index

    return "No negatives"


# Task 2: Invoking the function
scenario_1 = find_first_negative([3, 5, -1, 7, -2, 8])
scenario_2 = find_first_negative([2, 10, 7, 0])

print(f"Result 1: {scenario_1}")
print(f"Result 2: {scenario_2}")
# Out:
# Result 1: -1
# Result 2: No negatives

# %% [markdown]
# **7. Classes and Objects**
#
# *Task: Define a Car class with attributes and a description method.*

# %%
class Car:
    """
    Task 1: Define the Car class and its attributes.
    """
    def __init__(self, make, model, year):
        # We use 'self' to attach these values to the specific object being created
        self.make = make
        self.model = model
        self.year = year

    def describe_car(self):
        # We access the attributes using 'self.attribute_name'
        print(f"{self.year} {self.make} {self.model}")


# Task 2: Create an instance and call the method
my_car = Car("Toyota", "Corolla", 2020)
my_car.describe_car()
# Out:
# 2020 Toyota Corolla
